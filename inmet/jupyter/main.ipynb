# %%
import evapo
import inmet
import temp
import umi
import prec
import vento
import os
from dotenv import load_dotenv

# %%
#carrega a variavel .env
load_dotenv()

# chave de acesso
TOKEN = os.getenv('token')
URL = os.getenv('url')
URL_ST = os.getenv('url_st')

# %%
#Intervalo de tempo
data_inicial = '2023-01-01'
data_final = '2023-01-31'

# %%
#Lista as estações e retorna as estações do Espirito Santo
estacoes = inmet.get_estacoes('T')
estacoes = estacoes.groupby("SG_ESTADO").get_group("ES")
cod_estacao = list(estacoes["CD_ESTACAO"])

# %%
# Consulta as lista de estações cadastradas no inmet
result = inmet.sync_converter_router(data_inicial, data_final, cod_estacao)
result
# Out:
#              DC_NOME PRE_INS TEM_SEN   VL_LATITUDE PRE_MAX  UF RAD_GLO  \
# 0     AFONSO CLAUDIO   958.9    20.4  -20.10416666   959.1  ES    -2.7
# 1     AFONSO CLAUDIO   958.3    20.4  -20.10416666   958.9  ES    -3.1
# 2     AFONSO CLAUDIO   957.7    21.5  -20.10416666   958.4  ES    -3.3
# 3     AFONSO CLAUDIO   957.3    22.4  -20.10416666   957.7  ES    -3.1
# 4     AFONSO CLAUDIO   957.4      22  -20.10416666   957.4  ES      -3
# ...              ...     ...     ...           ...     ...  ..     ...
# 8923         VITÓRIA    1014    27.1  -20.27083332    1014  ES     9.2
# 8924         VITÓRIA  1014.9    26.9  -20.27083332  1014.9  ES    -3.5
# 8925         VITÓRIA  1015.8    26.5  -20.27083332  1015.8  ES    -3.5
# 8926         VITÓRIA  1016.2    25.9  -20.27083332  1016.3  ES    -3.5
# 8927         VITÓRIA  1015.9    25.6  -20.27083332  1016.3  ES    -3.5
#
#      PTO_INS TEM_MIN  VL_LONGITUDE  ... TEM_MAX TEN_BAT VEN_RAJ TEM_CPU  \
# 0       17.6    22.2  -41.10694444  ...    22.8    12.4     8.2      25
# 1         17    21.7  -41.10694444  ...    22.4    12.4     6.8      24
# 2         17    21.2  -41.10694444  ...    21.8    12.4     4.4      24
# 3       17.3    20.9  -41.10694444  ...    21.4    12.4     3.2      23
# 4       17.7    20.5  -41.10694444  ...      21    12.3       2      23
# ...      ...     ...           ...  ...     ...     ...     ...     ...
# 8923    20.8    26.5  -40.30583333  ...    27.4    12.6     7.1      29
# 8924    20.7      26  -40.30583333  ...    26.5    12.5     5.4      28
# 8925      21    24.9  -40.30583333  ...    26.1    12.6     5.5      28
# 8926    21.3    23.7  -40.30583333  ...    24.9    12.6     2.5      27
# 8927    21.5      23  -40.30583333  ...    23.7    12.6     1.9      26
#
#      TEM_INS UMD_INS CD_ESTACAO HR_MEDICAO       Data_Hora_UTC   ID
# 0       22.3      75       A657   00:00:00 2023-01-01 00:00:00    3
# 1       21.7      75       A657   01:00:00 2023-01-01 01:00:00    4
# 2       21.3      77       A657   02:00:00 2023-01-01 02:00:00    5
# 3         21      79       A657   03:00:00 2023-01-01 03:00:00    6
# 4       20.6      84       A657   04:00:00 2023-01-01 04:00:00    7
# ...      ...     ...        ...        ...                 ...  ...
# 8923    26.5      71       A612   19:00:00 2023-01-31 19:00:00  742
# 8924    26.1      72       A612   20:00:00 2023-01-31 20:00:00  743
# 8925    24.9      79       A612   21:00:00 2023-01-31 21:00:00  744
# 8926    23.7      87       A612   22:00:00 2023-01-31 22:00:00  745
# 8927    23.1      91       A612   23:00:00 2023-01-31 23:00:00  746
#
# [8928 rows x 29 columns]

# %%
#Realiza o calculo de temperatura minima absoluta,media e maxima absoluta do ar e retorna o grafico
result = temp.periodo_absoluto(data_inicial,data_final,cod_estacao)
temp.graf_temp(result)

# %%
#Realiza o calculo de media da temperatura minima ,media da instantanea e media da temperatura maxima absoluta do ar e retorna o grafico
result = temp.periodo_media(data_inicial,data_final,cod_estacao)
temp.graf_temp(result)

# %%
#
result = evapo.radiacao(data_inicial,data_final,cod_estacao)
print(result)
#evapo.graf_evap(result)

# %%
result = umi.periodo_media(data_inicial,data_final,cod_estacao)
umi.graf(result)

# %%
#Realiza o calculo de precipitação e retorna o grafico de todas as estações
result = evapo.radiacao(data_inicial,data_final,cod_estacao)
evapo.graf_prec(result)

# %%
#Realiza a distribuição de velocidade e direção do vento e retorna o grafico de todas as estações
result = evapo.radiacao(data_inicial, data_final, cod_estacao)
evapo.graf_prec_evap(result)

# %%
result = vento.periodo(data_inicial, data_final, cod_estacao)
vento.graf(result)

# %%
result = prec.precipitacao(data_inicial,data_final,cod_estacao)
result.tail(31)
#prec.graf_prec(result)
# Out:
#      DC_NOME  DT_MEDICAO  CHUVA
# 341  VITÓRIA  2023-01-01    0.0
# 342  VITÓRIA  2023-01-02    7.8
# 343  VITÓRIA  2023-01-03    0.0
# 344  VITÓRIA  2023-01-04    0.0
# 345  VITÓRIA  2023-01-05    0.2
# 346  VITÓRIA  2023-01-06    9.8
# 347  VITÓRIA  2023-01-07   23.6
# 348  VITÓRIA  2023-01-08    2.6
# 349  VITÓRIA  2023-01-09    0.0
# 350  VITÓRIA  2023-01-10    0.0
# 351  VITÓRIA  2023-01-11    0.0
# 352  VITÓRIA  2023-01-12    3.0
# 353  VITÓRIA  2023-01-13    0.0
# 354  VITÓRIA  2023-01-14    0.0
# 355  VITÓRIA  2023-01-15    0.0
# 356  VITÓRIA  2023-01-16    0.0
# 357  VITÓRIA  2023-01-17    6.8
# 358  VITÓRIA  2023-01-18    1.4
# 359  VITÓRIA  2023-01-19    9.8
# 360  VITÓRIA  2023-01-20   21.2
# 361  VITÓRIA  2023-01-21    6.4
# 362  VITÓRIA  2023-01-22   31.8
# 363  VITÓRIA  2023-01-23    0.6
# 364  VITÓRIA  2023-01-24   34.2
# 365  VITÓRIA  2023-01-25   22.0
# 366  VITÓRIA  2023-01-26    0.2
# 367  VITÓRIA  2023-01-27    0.0
# 368  VITÓRIA  2023-01-28    0.4
# 369  VITÓRIA  2023-01-29    0.0
# 370  VITÓRIA  2023-01-30    0.0
# 371  VITÓRIA  2023-01-31    0.0
